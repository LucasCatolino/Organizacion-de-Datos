# %%
import pandas as pd
from datetime import datetime
dtypes = {'ref_type': 'int8', 'event_id': 'int8', 'ref_hash': 'int8', 'application_id': 'int8', 'device_countrycode': 'int8', 'device_os_version': 'float32'}
parse_dates = ['date']


events = pd.read_csv('C:/Users/Alan Camussi/Desktop/data/events.csv.gzip', compression='gzip', iterator=True, dtype = dtypes, parse_dates = parse_dates, low_memory=False, error_bad_lines = False, chunksize=1000)
eventsdf = pd.concat(events, ignore_index=True)

eventsdf
# Out:
#                            date  event_id  ref_type  ref_hash  application_id  \
# 0       2019-03-05 00:09:36.966         0        -9       116              38
# 1       2019-03-05 00:09:38.920         1        -9       116              38
# 2       2019-03-05 00:09:26.195         0        -9       116              38
# 3       2019-03-05 00:09:31.107         2        -9       116              38
# 4       2019-03-09 21:00:36.585         3        -9        46              38
# 5       2019-03-09 20:29:45.449         4        -9        46              38
# 6       2019-03-09 20:29:40.602         5        -9        46              38
# 7       2019-03-09 20:45:12.067         0        -9        46              38
# 8       2019-03-09 20:40:07.977         0        -9        46              38
# 9       2019-03-09 20:27:09.984         1        -9        46              38
# 10      2019-03-09 20:27:12.583         0        -9        46              38
# ...
