# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from subprocess import check_output

# %matplotlib inline

plt.style.use('default')
sns.set(style="whitegrid")
pd.options.display.float_format= '{:20,.2f}'.format

# %%
clicks= pd.read_csv('C:/Users/Lucas/Documents/Datos TP/clicks.csv.gzip',compression='gzip',engine='python')
#clicks['dia'] = pd.to_datetime(clicks['created']).dt.date
#clicks['hora'] = pd.to_datetime(clicks['created']).dt.time
#clicks.drop(['created'], axis=1, inplace=True)
clicks['created'] = pd.to_datetime(clicks['created'], format='%Y/%m/%d %H:%M')
clicks['dia'] = pd.to_datetime(clicks['created']).dt.date
clicks['hora'] = pd.to_datetime(clicks['created']).dt.time
clicks.head()
# Out:
#    advertiser_id            action_id  source_id  \
# 0              2                  nan          4
# 1              0                  nan          0
# 2              0                  nan          0
# 3              2                  nan          3
# 4              2                  nan          3
#
#                            created         country_code             latitude  \
# 0 2019-03-06 22:42:12.755000+00:00  6333597102633388268                 1.21
# 1 2019-03-08 10:24:30.641000+00:00  6333597102633388268                 1.22
# 2 2019-03-08 15:24:16.069000+00:00  6333597102633388268                 1.21
# 3 2019-03-06 03:08:51.543000+00:00  6333597102633388268                 1.21
# 4 2019-03-06 03:32:55.570000+00:00  6333597102633388268                 1.21
#
#              longitude  wifi_connection           carrier_id  \
# 0                 1.07            False                 1.00
# 1                 1.07            False                 4.00
# 2                 1.07            False                 6.00
# 3                 1.07            False                45.00
# 4                 1.07            False                45.00
#
#                           trans_id  ...                     os_major  \
# 0  iGgClCM9exiHF4K31g94XmvHEBSLKIY  ... 3,072,849,339,937,028,096.00
# 1  MMHTOJ6qKAOeIH_Eywh1KIcCaxtO9oM  ... 1,774,085,102,589,090,048.00
# 2  vIrEIdf9izUaWdAri6Ezk7T3nHFvNQU  ... 3,072,849,339,937,028,096.00
# 3  YaKxxEAs2UmZhSpRfiCO9Zpa82B_AKM  ... 3,072,849,339,937,028,096.00
# 4  X5XTOcYQovkl6yadYdAD7xioVGU9jiY  ... 3,072,849,339,937,028,096.00
#
#            specs_brand                brand          timeToClick  \
# 0  2733035977666442898                  nan                 1.56
# 1   392184377613098015                  nan                  nan
# 2   392184377613098015                  nan                  nan
# 3  2733035977666442898                  nan                19.01
# 4  2733035977666442898                  nan                28.11
#
#                 touchX               touchY             ref_type  \
# 0                 0.91                 0.08  1891515180541284343
# 1                  nan                  nan  1891515180541284343
# 2                 0.95                 0.47  1891515180541284343
# 3                 0.04                 0.43  1891515180541284343
# 4                 0.05                 0.42  1891515180541284343
#
#               ref_hash         dia             hora
# 0  1904083516767779093  2019-03-06  22:42:12.755000
# 1  3086509764961796666  2019-03-08  10:24:30.641000
# 2  6958163894863846647  2019-03-08  15:24:16.069000
# 3  4368617728156436525  2019-03-06  03:08:51.543000
# 4  4368617728156436525  2019-03-06  03:32:55.570000
#
# [5 rows x 22 columns]

# %%
clicks['hora']= (clicks['created'].dt.hour*100+ clicks['created'].dt.minute)

# %%
dia1= clicks[(clicks['dia'].astype('str')== '2019-03-08')]
dia1['hora'].value_counts().plot(kind='bar', rot=0, figsize=(10,8), color='purple' ,fontsize=13);

plt.title('Cantidad de clicks en un dia', fontsize=20);
plt.xlabel('Viernes', fontsize=16);
plt.ylabel('Cantidad de clicks', fontsize=20);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-d79bbeddc866> in <module>()
#       1 dia1= clicks[(clicks['dia'].astype('str')== '2019-03-08')]
# ----> 2 dia1['hora'].countplot(kind='bar', rot=0, figsize=(10,8), color='purple' ,fontsize=13);
#       3
#       4 plt.title('Cantidad de clicks en un dia', fontsize=20);
#       5 plt.xlabel('Viernes', fontsize=16);
#
# C:\Users\Lucas\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'countplot'

# %%
clicks['dia'] = pd.to_datetime(clicks['created']).dt.date
clicks['hora'] = pd.to_datetime(clicks['created']).dt.time
clicks['date'] = pd.to_datetime(clicks['dia'])
clicks = clicks.set_index('date')
clicks.drop(['dia'], axis=1, inplace=True)
clicks.head()
# Out:
#             advertiser_id            action_id  source_id  \
# date
# 2019-03-06              2                  nan          4
# 2019-03-08              0                  nan          0
# 2019-03-08              0                  nan          0
# 2019-03-06              2                  nan          3
# 2019-03-06              2                  nan          3
#
#                              created         country_code  \
# date
# 2019-03-06  2019-03-06T22:42:12.755Z  6333597102633388268
# 2019-03-08  2019-03-08T10:24:30.641Z  6333597102633388268
# 2019-03-08  2019-03-08T15:24:16.069Z  6333597102633388268
# 2019-03-06  2019-03-06T03:08:51.543Z  6333597102633388268
# 2019-03-06  2019-03-06T03:32:55.570Z  6333597102633388268
#
#                        latitude            longitude  wifi_connection  \
# date
# 2019-03-06                 1.21                 1.07            False
# 2019-03-08                 1.22                 1.07            False
# 2019-03-08                 1.21                 1.07            False
# 2019-03-06                 1.21                 1.07            False
# 2019-03-06                 1.21                 1.07            False
#
#                      carrier_id                         trans_id  ...  \
# date                                                              ...
# 2019-03-06                 1.00  iGgClCM9exiHF4K31g94XmvHEBSLKIY  ...
# 2019-03-08                 4.00  MMHTOJ6qKAOeIH_Eywh1KIcCaxtO9oM  ...
# 2019-03-08                 6.00  vIrEIdf9izUaWdAri6Ezk7T3nHFvNQU  ...
# 2019-03-06                45.00  YaKxxEAs2UmZhSpRfiCO9Zpa82B_AKM  ...
# 2019-03-06                45.00  X5XTOcYQovkl6yadYdAD7xioVGU9jiY  ...
#
#                    agent_device                     os_major  \
# date
# 2019-03-06                  nan 3,072,849,339,937,028,096.00
# 2019-03-08                  nan 1,774,085,102,589,090,048.00
# 2019-03-08                  nan 3,072,849,339,937,028,096.00
# 2019-03-06                  nan 3,072,849,339,937,028,096.00
# 2019-03-06                  nan 3,072,849,339,937,028,096.00
#
#                     specs_brand                brand          timeToClick  \
# date
# 2019-03-06  2733035977666442898                  nan                 1.56
# 2019-03-08   392184377613098015                  nan                  nan
# 2019-03-08   392184377613098015                  nan                  nan
# 2019-03-06  2733035977666442898                  nan                19.01
# 2019-03-06  2733035977666442898                  nan                28.11
#
#                          touchX               touchY             ref_type  \
# date
# 2019-03-06                 0.91                 0.08  1891515180541284343
# 2019-03-08                  nan                  nan  1891515180541284343
# 2019-03-08                 0.95                 0.47  1891515180541284343
# 2019-03-06                 0.04                 0.43  1891515180541284343
# 2019-03-06                 0.05                 0.42  1891515180541284343
#
#                        ref_hash             hora
# date
# 2019-03-06  1904083516767779093  22:42:12.755000
# 2019-03-08  3086509764961796666  10:24:30.641000
# 2019-03-08  6958163894863846647  15:24:16.069000
# 2019-03-06  4368617728156436525  03:08:51.543000
# 2019-03-06  4368617728156436525  03:32:55.570000
#
# [5 rows x 21 columns]

# %%
clicks['datetime'] = pd.to_datetime(clicks['created'])
clicks = clicks.set_index('datetime')
clicks.drop(['created'], axis=1, inplace=True)
